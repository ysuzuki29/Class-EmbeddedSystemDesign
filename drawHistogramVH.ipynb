# %%
# -*- coding: utf-8 -*-
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4c09b42c-3441-4df2-b1c1-f5d3c6924e1b" name="files[]" multiple disabled />
#      <output id="result-4c09b42c-3441-4df2-b1c1-f5d3c6924e1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving img016a.jpg to img016a.jpg

# %%
# -*- coding: utf-8 -*-
# usage: drawHistogramVM.py jpgfilename
import cv2
import sys
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

#filename=sys.argv[1]

img_src = cv2.imread("img016a.jpg",0)

print(img_src)

print(img_src.shape)

height=img_src.shape[0]
width=img_src.shape[1]

img_resize=cv2.resize(img_src, (int(width/8), int(height/8)))

cv2_imshow(img_resize)

transpose_img=img_resize.transpose(1,0)
#clockwise_img=transpose_img[:,::-1]
counter_clockwise_img=transpose_img[::-1]
#cv2_imshow(clockwise_img)
cv2_imshow(counter_clockwise_img)


k=cv2.waitKey(0)
cv2.destroyAllWindows()

#arr=img_src.cumsum(0) # Horizontal
arr=img_src.T.cumsum(0) # Vertical

print(arr)
print(arr[-1])

x=np.arange(0, len(arr[-1]))
y=arr[-1]

print(x)
print(y)

plt.plot(x,y)

plt.show()

#img_dist=cv2.rectangle(cv2.resize(img_src, (width/8, height/8)), (100, 100), (200, 200), 256, thickness=2)
img_dist=cv2.rectangle(img_src, (100, 100), (200, 200), 256, thickness=2)

#cv2.imshow('dist', cv2.resize(img_dist, (width/8, height/8)))
cv2_imshow(img_dist)
k=cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# (3500, 939)
# <PIL.Image.Image image mode=L size=117x437 at 0x7F483A10A6D8>
# <PIL.Image.Image image mode=L size=437x117 at 0x7F4835FE9F98>
# [[   255    255    255 ...    255    255    255]
#  [   510    510    510 ...    510    510    510]
#  [   765    765    765 ...    765    765    765]
#  ...
#  [238935 238935 238935 ... 238935 238935 238935]
#  [239190 239190 239190 ... 239190 239190 239190]
#  [239445 239445 239445 ... 239445 239445 239445]]
# [239445 239445 239445 ... 239445 239445 239445]
# [   0    1    2 ... 3497 3498 3499]
# [239445 239445 239445 ... 239445 239445 239445]
# <PIL.Image.Image image mode=L size=939x3500 at 0x7F4835FC7F60>
