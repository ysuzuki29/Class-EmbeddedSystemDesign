# %% [markdown]
# sampling frequency
# 40 1F(LE)   ->   0x1F 40

# %%
1*16**3+15*16**2+4*16**1+0
# Out:
# 8000

# %% [markdown]
# size of aaaaa.wav
# 56 71(LE)    ->     0x71 56
# 56 71(LE) = file size - 8

# %%
7*16**3+1*16**2+5*16**1+6+8
# Out:
# 29022

# %% [markdown]
# 80 3E(LE) -> 0x3E80
