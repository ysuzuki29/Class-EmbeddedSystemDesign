# %%
import tensorflow as tf

input1 = tf.ones((3, 3))
input2 = tf.reshape(tf.range(1, 10, dtype=tf.float32), (3, 3))
output = input1 + input2

with tf.Session():
  result = output.eval()
result
# Out:
# array([[ 2.,  3.,  4.],
#        [ 5.,  6.,  7.],
#        [ 8.,  9., 10.]], dtype=float32)

# %%
3+1
# Out:
# 4
